# %% [markdown]
# ![title](https://www.otexts.org/sites/default/files/fpp/images/decomp1.png)

# %% [markdown]
# A time series is a plot that visualizes the change of a value over time. It looks like a lot of lines, changing over time, but there is a lot of meaning hidden inside these informative lines. We'll go through visualizing time series data, and then we'll go on around dealing with Non-Stationary time series data.

# %% [markdown]
# ## Visualizing Time Series
#
# First, let's load our dataset, of arrivals to Australia.

# %%
import pandas as pd
aus = pd.read_csv("australia.csv")
aus.head()
# Out:
#       Date  Number of arrivals
# 0  1991M01               27566
# 1  1991M02               27621
# 2  1991M03               25696
# 3  1991M04               21653
# 4  1991M05               21197

# %% [markdown]
# Since our date column is not standarized, we'll first turn it into a proper date, by replacing that M with a dash (-) and adding an arbitrary day (in this case, the first of the month).

# %%
def Clean_Date(date):
    date = date.replace("M","-")
    date = date + "-01"
    return date

aus.Date = aus.Date.apply(Clean_Date)
aus.head()
# Out:
#          Date  Number of arrivals
# 0  1991-01-01               27566
# 1  1991-02-01               27621
# 2  1991-03-01               25696
# 3  1991-04-01               21653
# 4  1991-05-01               21197

# %% [markdown]
# There's one more thing we need to do. We need to convert our date column to a **datetime** type object. This is the best type for working with dates in Python, as it's easier for the rest of our functions to understand. For this, we use the pandas to_datetime function.

# %%
aus.Date = pd.to_datetime(aus.Date)
aus.head()
# Out:
#         Date  Number of arrivals
# 0 1991-01-01               27566
# 1 1991-02-01               27621
# 2 1991-03-01               25696
# 3 1991-04-01               21653
# 4 1991-05-01               21197

# %%
aus.Date[0]
# Out:
# 1

# %% [markdown]
# Now we can start plotting. If you have a dataset that doesn't contain a formatted date column, then you can create one yourself! But since we comfortably have one already, let's just use it. To plot time series data, we can just use the matplotlib **plot** function.

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams 
#Our usual Parameter function.
def MatplotLib_Params():
    #The size of the figure.
    rcParams['figure.figsize'] = (8, 6)
    #Dots per inch or resolution of the figure.
    rcParams['figure.dpi'] = 150
    #Size of the letters and numbers in the plot.
    rcParams['font.size'] = 14
    
#Set the date column as the index of the dataframe, it's very important to do this!
aus = aus.set_index("Date")
MatplotLib_Params()
plt.plot(aus)
plt.show()

# %% [markdown]
# As we can see, the number of arrivals steadily increased over the years, where it goes up and down each year. Overall, there's an increasing **overall trend** , with some spikes on certain years. We can see plots for certain dates by slicing the dates like we do with lists and dataframes.

# %%
plt.plot(aus['2000-01-01':])
plt.xticks(rotation = 70) #Rotate the X axis for better visibility.
plt.show()

# %% [markdown]
# Looks like most arrivals happen in December, which makes sense since people want to be with their family over the holidays.

# %% [markdown]
# #### Your turn now
# Plot the time series for the Australian dataset, for dates before 1996.

# %%
#Your code here.

# %% [markdown]
# ## Checking Stationarity of a Time Series.
#
# A time series is said to be **stationary** if the mean and variance do not change over time, and its autocovariance doesn't depend on time. It may sound confusing, but let's visualize the rolling mean and variance of our pros time series, so you can get a clearer picture.

# %%
def plot_Statistics(data):
    #Calculate rolling mean and standard deviation.
    
    rmean = data.rolling(window= 12,center = False).mean() #Yearly window.
    rstd = data.rolling(window=12,center = False).std() 

    #Plot data and rolling statistics
    dataplot = plt.plot(data, color='blue',label='Time Series')
    meanplot = plt.plot(rmean, color='red', label='Rolling mean')
    stdplot = plt.plot(rstd, color='green', label = 'Rolling standard deviation')
    plt.legend(loc='best')
    plt.show()
    

plot_Statistics(aus)

# %% [markdown]
# For our full time series, the mean and standard deviation are not constant, so this time series is **not** stationary. What makes it this way? One of them is the **Trend**. The trend is the overall direction the data is going over time. In this case, the arrivals to Australia are **increasing** over time.  The other one is the **Seasonal Component**. As we saw in plots before, most arrivals come in the holidays, summer and early spring while the least arrivals happen at May. This means this changes in values happen at some points in time, or a **season**.

# %% [markdown]
# ## Removing non-stationarity in a Time Series

# %% [markdown]
# ### Removing Trend using Moving Averages.
#
# We can use several methods for removing the Trend of a time series, but in this notebook, we'll use the **Moving Averages** method. First, let's visualize the time series with a **transformation**, which punishes higher values of the trend, and makes the range of the values smaller.

# %%
import numpy as np
aus_log = np.log(aus)
plt.plot(aus_log)
plt.show()

# %% [markdown]
# Next, let's plot the rolling mean of the time series, like we did before. This is the **moving average** of the time series.

# %%
moving_average = aus_log.rolling(window= 12,center = False).mean() #Yearly window.
plt.plot(aus_log)
plt.plot(moving_average, color='black')
plt.show()

# %% [markdown]
# Now, let's substract it from the original time series, to get the difference. This will create some NaN values for some months.

# %%
m_avg_diff = aus_log - moving_average
m_avg_diff.head(24)
# Out:
#             Number of arrivals
# Date
# 1991-01-01                 NaN
# 1991-02-01                 NaN
# 1991-03-01                 NaN
# 1991-04-01                 NaN
# 1991-05-01                 NaN
# 1991-06-01                 NaN
# 1991-07-01                 NaN
# 1991-08-01                 NaN
# 1991-09-01                 NaN
# 1991-10-01                 NaN
# 1991-11-01                 NaN
# 1991-12-01            0.494403
# 1992-01-01            0.073655
# 1992-02-01            0.082205
# 1992-03-01            0.146622
# 1992-04-01            0.035385
# 1992-05-01           -0.260272
# 1992-06-01           -0.037879
# 1992-07-01            0.116376
# 1992-08-01           -0.168347
# 1992-09-01            0.075152
# 1992-10-01           -0.088958
# 1992-11-01           -0.000068
# 1992-12-01            0.488598

# %% [markdown]
# Finally, let's remove the NaN rows, and plot the statistics again.

# %%
m_avg_diff.dropna(inplace=True)
plot_Statistics(m_avg_diff)
plt.show()

# %% [markdown]
# See the difference? This time series doesn't have an upwards trend like the original one, which effectively means we reduced the trend. We can prove this statistically using an Dickey-Fueller test for stationarity. In case you don't know about it, you can learn about it here : https://en.wikipedia.org/wiki/Augmented_Dickey%E2%80%93Fuller_test.

# %%
from statsmodels.tsa.stattools import adfuller
def DFueller_test(time_series):
    test = adfuller(time_series["Number of arrivals"], autolag='AIC')
    result = pd.Series(test[0:4], index=['Test Statistic','p-value','#Lags','Number of Observations'])
    for key,value in test[4].items():
        result['Critical Value (%s)'%key] = value
    print(result)
    
DFueller_test(m_avg_diff)
# Out:
# Test Statistic             -2.901417
# p-value                     0.045184
# #Lags                      13.000000
# Number of Observations    103.000000
# Critical Value (1%)        -3.495493
# Critical Value (5%)        -2.890037
# Critical Value (10%)       -2.581971
# dtype: float64

# %% [markdown]
# Since the test statistic is lower than the 5%, we can say with 95% confidence that the time series is stationary.

# %% [markdown]
# Another method we could use is the **exponentially weighted** moving averages, where more recent values are given more weight, in case the time series trend changes frequently. This can also be implemented in pandas, but I'll leave that to you. Sometimes, exponentially weighted moving averages can give better results than regular ones, but it depends on the domain where you are using them. The docs for it in pandas can be found here: http://pandas.pydata.org/pandas-docs/stable/computation.html#exponentially-weighted-moment-functions

# %% [markdown]
# ### Differencing
#
# Another method is differencing, where the difference between an observation and the previous one is calculated. Some of these are first order, second order and third order differentiations.

# %%
first_diff =  aus_log.diff(1) #The order of differentiation.
first_diff.dropna(inplace=True)
plot_Statistics(first_diff)
DFueller_test(first_diff)
# Out:
# Test Statistic           -6.832887e+00
# p-value                   1.874081e-09
# #Lags                     1.100000e+01
# Number of Observations    1.150000e+02
# Critical Value (1%)      -3.488535e+00
# Critical Value (5%)      -2.887020e+00
# Critical Value (10%)     -2.580360e+00
# dtype: float64

# %% [markdown]
# This gives us the least changing rolling mean so far. Try different order values to see some differences!

# %% [markdown]
# ### Decomposition
#
# In this method, the trend and seasonality are modeled separately, and we model the residual of the time series. Once again, we can use the **statsmodels** package to help with this :

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

decompose = seasonal_decompose(aus_log)

trend = decompose.trend
seasonal = decompose.seasonal
residual = decompose.resid
# Out:
# C:\Users\jununez\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\tsa\filters\filtertools.py:28: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return np.r_[[np.nan] * head, x, [np.nan] * tail]

# %% [markdown]
# Now, let's plot all three in one place.

# %%
#Create various subplots.
plt.subplot(411)
plt.plot(trend, label='Trend')

plt.subplot(412)
plt.plot(seasonal,label='Seasonality')

plt.subplot(413)
plt.plot(residual, label='Residuals')

#Specify the layout of the plots.
plt.tight_layout()
plt.show()

# %% [markdown]
# The first plot is the trend. As we've analyzed before, the trend is increasing over the years, since the number of arrivals is steadily increasing each year.
#
# The second plot is the seasonality. Again, arrivals peak in holidays, and reach the bottom at around may.
#
# The third plot is the residual, or what's left of the time series after removing the Trend and Seasonality.
#
# Let's check stationarity for the residual.

# %%
decomp_ts = residual
decomp_ts.dropna(inplace=True)
plot_Statistics(decomp_ts)
DFueller_test(decomp_ts)
# Out:
# Test Statistic           -6.595245e+00
# p-value                   6.951834e-09
# #Lags                     1.300000e+01
# Number of Observations    1.020000e+02
# Critical Value (1%)      -3.496149e+00
# Critical Value (5%)      -2.890321e+00
# Critical Value (10%)     -2.582122e+00
# dtype: float64

# %% [markdown]
# Just like with the differentiation time series, this one is very close to stationary. Both have a test statistics lower than the 1% critical value. We can use any of them for the forecasting using the time series, but we'll see that in a much later notebook. In this one, we were just introducing Time Series, and time series plots.
#
# ## Further Reading
#
# - Time series: https://onlinecourses.science.psu.edu/stat510/node/47
#
# ## Exercise
#
# Perform Time series analysis on the Shampoo Dataset.
