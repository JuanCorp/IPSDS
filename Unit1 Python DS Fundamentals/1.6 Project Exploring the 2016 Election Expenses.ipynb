# %% [markdown]
# In this project, you are free to practice what you learned on this unit so far, on the **2016 Election Expenses** dataset. Some examples of what you can do are:
#
# - Selecting only the cleanest columns of the dataset.
# - Grouping the data by different columns.
# - Poke around working with dates (hint: pd.to_datetime)
# - Perform calculations regarding the expenses.
# - Present your insights and analysis of the data at hand.
#
#
# I'll give you the first 3 cells of code so you get an idea of the data. Have fun!

# %%
import pandas as pd
Expenses = pd.read_csv("expenditures.csv")

# %%
#Hint NaN means not assigned, or empty. 
Expenses.head(10)
# Out:
#   committee_id candidate_id candidate_name                recipient_name  \
# 0    C00458844    P60006723   RUBIO, MARCO              GREEN, PERRY MR.
# 1    C00458844    P60006723   RUBIO, MARCO       ALASKA REPUBLICAN PARTY
# 2    C00458844    P60006723   RUBIO, MARCO                 JOHNSON, MARK
# 3    C00458844    P60006723   RUBIO, MARCO                    ENTERPRISE
# 4    C00458844    P60006723   RUBIO, MARCO  U.S. SPACE AND ROCKET CENTER
# 5    C00458844    P60006723   RUBIO, MARCO               MINUTEMAN PRESS
# 6    C00458844    P60006723   RUBIO, MARCO      ALABAMA REPUBLICAN PARTY
# 7    C00458844    P60006723   RUBIO, MARCO       GUNTERSVILLE REC CENTER
# 8    C00458844    P60006723   RUBIO, MARCO    GARCIA-NOWLIN, DEBBIE MRS.
# 9    C00458844    P60006723   RUBIO, MARCO          NOWLIN, HENRY M. MR.
#
#    disbursement_amount disbursement_date recipient_city recipient_state  \
# 0               500.00         15-Sep-15      ANCHORAGE              AK
# ...

# %%
Expenses.tail(10)
# Out:
#       committee_id candidate_id           candidate_name  \
# 65489    C00575795    P00003392  CLINTON, HILLARY RODHAM
# 65490    C00575795    P00003392  CLINTON, HILLARY RODHAM
# 65491    C00575795    P00003392  CLINTON, HILLARY RODHAM
# 65492    C00575795    P00003392  CLINTON, HILLARY RODHAM
# 65493    C00575795    P00003392  CLINTON, HILLARY RODHAM
# 65494    C00575795    P00003392  CLINTON, HILLARY RODHAM
# 65495    C00575795    P00003392  CLINTON, HILLARY RODHAM
# 65496    C00575795    P00003392  CLINTON, HILLARY RODHAM
# 65497    C00575795    P00003392  CLINTON, HILLARY RODHAM
# 65498    C00575795    P00003392  CLINTON, HILLARY RODHAM
#
#                                           recipient_name  disbursement_amount  \
# 65489                     IOWA WESTERN COMMUNITY COLLEGE               350.00
# 65490                                       JOYCE, LOUIS              1106.39
# 65491                     ELITE PRODUCTIONS SERVICES LLC             11090.00
# ...

# %%
## The rest is up to you.
